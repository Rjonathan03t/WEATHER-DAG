# %% [markdown]
# # **Analyse Exploratoire de Données (AED)**

# %% [markdown]
# ## **1. Chargement et Aperçu des Données**

# %%
# Importation des bibliothèques nécessaires
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
# Out:
# \\wsl.localhost\Ubuntu\home\tokiniaina\weather\WEATHER-DAG\script

# %%
#Importer les fichiers
pollution_file_path = '../data/raw/Pollution_With_Demographic.csv'
demographic_file_path = '../data/raw/Pollution_With_Geographic.csv'
# Lire les fichiers CSV
df_pollution = pd.read_csv(pollution_file_path)
df_demographic = pd.read_csv(demographic_file_path)

# %% [markdown]
# ## **2. Analyse des Correlations et Tendances**

# %% [markdown]
# ### Analyse Correlations

# %%
df = pd.merge(df_pollution, df_demographic, on='Location')
def analyze_correlations(df):
    numeric_df = df.select_dtypes(include=['number'])
    
    correlations = numeric_df.corr()

    print("Corrélations entre les niveaux de pollution et les facteurs démographiques et géographiques:")
    print(correlations)

    plt.figure(figsize=(14, 10))
    sns.heatmap(correlations, annot=True, cmap='coolwarm', fmt='.2f')
    plt.title('Corrélations entre les niveaux de pollution et les facteurs démographiques et géographiques')
    plt.show()
analyze_correlations(df)
# Out:
# Corrélations entre les niveaux de pollution et les facteurs démographiques et géographiques:
#                                                Population  \
# Population                                       1.000000
# Density (people/km²)                            -0.406757
# Urbanization (%)                                 0.490486
# Average Income (USD)                             0.503947
# Education Level (% with Bachelor's or higher)    0.604280
# AQI_x                                            0.550836
# CO_x                                            -0.242316
# NO_x                                            -0.339490
# NO2_x                                            0.542456
# O3_x                                             0.104008
# SO2_x                                            0.946687
# PM2_5_x                                         -0.105858
# PM10_x                                          -0.192249
# NH3_x                                           -0.346480
# Altitude (m)                                    -0.335901
# Proximity to Industry (km)                       0.341450
# AQI_y                                            0.550836
# CO_y                                            -0.242316
# NO_y                                            -0.339490
# NO2_y                                            0.542456
# O3_y                                             0.104008
# SO2_y                                            0.946687
# PM2_5_y                                         -0.105858
# PM10_y                                          -0.192249
# NH3_y                                           -0.346480
#
#                                                Density (people/km²)  \
# Population                                                -0.406757
# Density (people/km²)                                       1.000000
# Urbanization (%)                                           0.472731
# Average Income (USD)                                       0.321674
# Education Level (% with Bachelor's or higher)              0.326652
# AQI_x                                                     -0.315332
# CO_x                                                      -0.120645
# NO_x                                                       0.877228
# NO2_x                                                     -0.250843
# O3_x                                                      -0.325983
# SO2_x                                                     -0.434017
# PM2_5_x                                                    0.183179
# PM10_x                                                     0.070994
# NH3_x                                                     -0.242211
# Altitude (m)                                              -0.454805
# Proximity to Industry (km)                                 0.203067
# AQI_y                                                     -0.315332
# CO_y                                                      -0.120645
# NO_y                                                       0.877228
# NO2_y                                                     -0.250843
# O3_y                                                      -0.325983
# SO2_y                                                     -0.434017
# PM2_5_y                                                    0.183179
# PM10_y                                                     0.070994
# NH3_y                                                     -0.242211
#
#                                                Urbanization (%)  \
# Population                                             0.490486
# Density (people/km²)                                   0.472731
# Urbanization (%)                                       1.000000
# Average Income (USD)                                   0.858783
# Education Level (% with Bachelor's or higher)          0.907069
# AQI_x                                                  0.023243
# CO_x                                                  -0.642161
# NO_x                                                   0.549518
# NO2_x                                                  0.385085
# O3_x                                                  -0.277023
# SO2_x                                                  0.280681
# PM2_5_x                                               -0.291044
# PM10_x                                                -0.475128
# NH3_x                                                 -0.817810
# Altitude (m)                                          -0.901866
# Proximity to Industry (km)                             0.600294
# AQI_y                                                  0.023243
# CO_y                                                  -0.642161
# NO_y                                                   0.549518
# NO2_y                                                  0.385085
# O3_y                                                  -0.277023
# SO2_y                                                  0.280681
# PM2_5_y                                               -0.291044
# PM10_y                                                -0.475128
# NH3_y                                                 -0.817810
#
#                                                Average Income (USD)  \
# Population                                                 0.503947
# Density (people/km²)                                       0.321674
# Urbanization (%)                                           0.858783
# Average Income (USD)                                       1.000000
# Education Level (% with Bachelor's or higher)              0.976342
# AQI_x                                                      0.424685
# CO_x                                                      -0.283452
# NO_x                                                       0.526238
# NO2_x                                                      0.684949
# O3_x                                                      -0.314703
# SO2_x                                                      0.303090
# PM2_5_x                                                   -0.103676
# PM10_x                                                    -0.307472
# NH3_x                                                     -0.499298
# Altitude (m)                                              -0.960407
# Proximity to Industry (km)                                 0.828404
# AQI_y                                                      0.424685
# CO_y                                                      -0.283452
# NO_y                                                       0.526238
# NO2_y                                                      0.684949
# O3_y                                                      -0.314703
# SO2_y                                                      0.303090
# PM2_5_y                                                   -0.103676
# PM10_y                                                    -0.307472
# NH3_y                                                     -0.499298
#
#                                                Education Level (% with Bachelor's or higher)  \
# Population                                                                          0.604280
# Density (people/km²)                                                                0.326652
# Urbanization (%)                                                                    0.907069
# Average Income (USD)                                                                0.976342
# Education Level (% with Bachelor's or higher)                                       1.000000
# AQI_x                                                                               0.427282
# CO_x                                                                               -0.353066
# NO_x                                                                                0.447304
# NO2_x                                                                               0.582265
# O3_x                                                                               -0.191447
# SO2_x                                                                               0.431568
# PM2_5_x                                                                            -0.140859
# PM10_x                                                                             -0.341827
# NH3_x                                                                              -0.549243
# Altitude (m)                                                                       -0.935144
# Proximity to Industry (km)                                                          0.721881
# AQI_y                                                                               0.427282
# CO_y                                                                               -0.353066
# NO_y                                                                                0.447304
# NO2_y                                                                               0.582265
# O3_y                                                                               -0.191447
# SO2_y                                                                               0.431568
# PM2_5_y                                                                            -0.140859
# PM10_y                                                                             -0.341827
# NH3_y                                                                              -0.549243
#
#                                                   AQI_x      CO_x      NO_x  \
# Population                                     0.550836 -0.242316 -0.339490
# Density (people/km²)                          -0.315332 -0.120645  0.877228
# Urbanization (%)                               0.023243 -0.642161  0.549518
# Average Income (USD)                           0.424685 -0.283452  0.526238
# Education Level (% with Bachelor's or higher)  0.427282 -0.353066  0.447304
# AQI_x                                          1.000000  0.510369 -0.258327
# CO_x                                           0.510369  1.000000 -0.108672
# NO_x                                          -0.258327 -0.108672  1.000000
# NO2_x                                          0.506693  0.070675  0.176372
# O3_x                                           0.230613 -0.065434 -0.676140
# SO2_x                                          0.629436 -0.019251 -0.474163
# PM2_5_x                                        0.311931  0.824324  0.217494
# PM10_x                                         0.238071  0.864373  0.071766
# NH3_x                                          0.426848  0.941295 -0.322774
# Altitude (m)                                  -0.204269  0.456119 -0.624275
# Proximity to Industry (km)                     0.335410  0.001383  0.588650
# AQI_y                                          1.000000  0.510369 -0.258327
# CO_y                                           0.510369  1.000000 -0.108672
# NO_y                                          -0.258327 -0.108672  1.000000
# NO2_y                                          0.506693  0.070675  0.176372
# O3_y                                           0.230613 -0.065434 -0.676140
# SO2_y                                          0.629436 -0.019251 -0.474163
# PM2_5_y                                        0.311931  0.824324  0.217494
# PM10_y                                         0.238071  0.864373  0.071766
# NH3_y                                          0.426848  0.941295 -0.322774
#
#                                                   NO2_x      O3_x  ...  \
# Population                                     0.542456  0.104008  ...
# Density (people/km²)                          -0.250843 -0.325983  ...
# Urbanization (%)                               0.385085 -0.277023  ...
# Average Income (USD)                           0.684949 -0.314703  ...
# Education Level (% with Bachelor's or higher)  0.582265 -0.191447  ...
# AQI_x                                          0.506693  0.230613  ...
# CO_x                                           0.070675 -0.065434  ...
# NO_x                                           0.176372 -0.676140  ...
# NO2_x                                          1.000000 -0.559848  ...
# O3_x                                          -0.559848  1.000000  ...
# SO2_x                                          0.366413  0.245583  ...
# PM2_5_x                                        0.167376 -0.448096  ...
# PM10_x                                         0.040690 -0.354649  ...
# NH3_x                                         -0.171424  0.216647  ...
# Altitude (m)                                  -0.525872  0.285871  ...
# Proximity to Industry (km)                     0.896058 -0.734879  ...
# AQI_y                                          0.506693  0.230613  ...
# CO_y                                           0.070675 -0.065434  ...
# NO_y                                           0.176372 -0.676140  ...
# NO2_y                                          1.000000 -0.559848  ...
# O3_y                                          -0.559848  1.000000  ...
# SO2_y                                          0.366413  0.245583  ...
# PM2_5_y                                        0.167376 -0.448096  ...
# PM10_y                                         0.040690 -0.354649  ...
# NH3_y                                         -0.171424  0.216647  ...
#
#                                                Proximity to Industry (km)  \
# Population                                                       0.341450
# Density (people/km²)                                             0.203067
# Urbanization (%)                                                 0.600294
# Average Income (USD)                                             0.828404
# Education Level (% with Bachelor's or higher)                    0.721881
# AQI_x                                                            0.335410
# CO_x                                                             0.001383
# NO_x                                                             0.588650
# NO2_x                                                            0.896058
# O3_x                                                            -0.734879
# SO2_x                                                            0.143618
# PM2_5_x                                                          0.240343
# PM10_x                                                           0.063630
# NH3_x                                                           -0.297692
# Altitude (m)                                                    -0.735077
# Proximity to Industry (km)                                       1.000000
# AQI_y                                                            0.335410
# CO_y                                                             0.001383
# NO_y                                                             0.588650
# NO2_y                                                            0.896058
# O3_y                                                            -0.734879
# SO2_y                                                            0.143618
# PM2_5_y                                                          0.240343
# PM10_y                                                           0.063630
# NH3_y                                                           -0.297692
#
#                                                   AQI_y      CO_y      NO_y  \
# Population                                     0.550836 -0.242316 -0.339490
# Density (people/km²)                          -0.315332 -0.120645  0.877228
# Urbanization (%)                               0.023243 -0.642161  0.549518
# Average Income (USD)                           0.424685 -0.283452  0.526238
# Education Level (% with Bachelor's or higher)  0.427282 -0.353066  0.447304
# AQI_x                                          1.000000  0.510369 -0.258327
# CO_x                                           0.510369  1.000000 -0.108672
# NO_x                                          -0.258327 -0.108672  1.000000
# NO2_x                                          0.506693  0.070675  0.176372
# O3_x                                           0.230613 -0.065434 -0.676140
# SO2_x                                          0.629436 -0.019251 -0.474163
# PM2_5_x                                        0.311931  0.824324  0.217494
# PM10_x                                         0.238071  0.864373  0.071766
# NH3_x                                          0.426848  0.941295 -0.322774
# Altitude (m)                                  -0.204269  0.456119 -0.624275
# Proximity to Industry (km)                     0.335410  0.001383  0.588650
# AQI_y                                          1.000000  0.510369 -0.258327
# CO_y                                           0.510369  1.000000 -0.108672
# NO_y                                          -0.258327 -0.108672  1.000000
# NO2_y                                          0.506693  0.070675  0.176372
# O3_y                                           0.230613 -0.065434 -0.676140
# SO2_y                                          0.629436 -0.019251 -0.474163
# PM2_5_y                                        0.311931  0.824324  0.217494
# PM10_y                                         0.238071  0.864373  0.071766
# NH3_y                                          0.426848  0.941295 -0.322774
#
#                                                   NO2_y      O3_y     SO2_y  \
# Population                                     0.542456  0.104008  0.946687
# Density (people/km²)                          -0.250843 -0.325983 -0.434017
# Urbanization (%)                               0.385085 -0.277023  0.280681
# Average Income (USD)                           0.684949 -0.314703  0.303090
# Education Level (% with Bachelor's or higher)  0.582265 -0.191447  0.431568
# AQI_x                                          0.506693  0.230613  0.629436
# CO_x                                           0.070675 -0.065434 -0.019251
# NO_x                                           0.176372 -0.676140 -0.474163
# NO2_x                                          1.000000 -0.559848  0.366413
# O3_x                                          -0.559848  1.000000  0.245583
# SO2_x                                          0.366413  0.245583  1.000000
# PM2_5_x                                        0.167376 -0.448096  0.078003
# PM10_x                                         0.040690 -0.354649  0.025287
# NH3_x                                         -0.171424  0.216647 -0.093112
# Altitude (m)                                  -0.525872  0.285871 -0.101620
# Proximity to Industry (km)                     0.896058 -0.734879  0.143618
# AQI_y                                          0.506693  0.230613  0.629436
# CO_y                                           0.070675 -0.065434 -0.019251
# NO_y                                           0.176372 -0.676140 -0.474163
# NO2_y                                          1.000000 -0.559848  0.366413
# O3_y                                          -0.559848  1.000000  0.245583
# SO2_y                                          0.366413  0.245583  1.000000
# PM2_5_y                                        0.167376 -0.448096  0.078003
# PM10_y                                         0.040690 -0.354649  0.025287
# NH3_y                                         -0.171424  0.216647 -0.093112
#
#                                                 PM2_5_y    PM10_y     NH3_y
# Population                                    -0.105858 -0.192249 -0.346480
# Density (people/km²)                           0.183179  0.070994 -0.242211
# Urbanization (%)                              -0.291044 -0.475128 -0.817810
# Average Income (USD)                          -0.103676 -0.307472 -0.499298
# Education Level (% with Bachelor's or higher) -0.140859 -0.341827 -0.549243
# AQI_x                                          0.311931  0.238071  0.426848
# CO_x                                           0.824324  0.864373  0.941295
# NO_x                                           0.217494  0.071766 -0.322774
# NO2_x                                          0.167376  0.040690 -0.171424
# O3_x                                          -0.448096 -0.354649  0.216647
# SO2_x                                          0.078003  0.025287 -0.093112
# PM2_5_x                                        1.000000  0.977268  0.624385
# PM10_x                                         0.977268  1.000000  0.720034
# NH3_x                                          0.624385  0.720034  1.000000
# Altitude (m)                                   0.278418  0.473642  0.628539
# Proximity to Industry (km)                     0.240343  0.063630 -0.297692
# AQI_y                                          0.311931  0.238071  0.426848
# CO_y                                           0.824324  0.864373  0.941295
# NO_y                                           0.217494  0.071766 -0.322774
# NO2_y                                          0.167376  0.040690 -0.171424
# O3_y                                          -0.448096 -0.354649  0.216647
# SO2_y                                          0.078003  0.025287 -0.093112
# PM2_5_y                                        1.000000  0.977268  0.624385
# PM10_y                                         0.977268  1.000000  0.720034
# NH3_y                                          0.624385  0.720034  1.000000
#
# [25 rows x 25 columns]

# %% [markdown]
# ### Analyse des Tendances

# %% [markdown]
# #### Tendance du AQI en fonction de l'altitude

# %%
def plot_aqi_vs_altitude(df):
    aqi_col = 'AQI_x'  
    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=df, x='Altitude (m)', y=aqi_col)
    plt.title('Tendance du AQI en fonction de l\'altitude')
    plt.xlabel('Altitude (m)')
    plt.ylabel(aqi_col)
    plt.show()
plot_aqi_vs_altitude(df)

# %% [markdown]
# #### Tendance du AQI en fonction de la proximite des industries

# %%
def plot_aqi_vs_proximity(df):
    aqi_col = 'AQI_x' 
    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=df, x='Proximity to Industry (km)', y=aqi_col)
    plt.title('Tendance du AQI en fonction de la proximité des industries')
    plt.xlabel('Proximité aux industries (km)')
    plt.ylabel(aqi_col)
    plt.show()
plot_aqi_vs_proximity(df)

# %% [markdown]
# #### Tendance en AQI en Fonction de la Densite

# %%
def plot_aqi_vs_density(df):
    aqi_col = 'AQI_x'
    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=df, x='Density (people/km²)', y=aqi_col)
    plt.title('Tendance du AQI en fonction de la densité de population')
    plt.xlabel('Densité (personnes/km²)')
    plt.ylabel(aqi_col)
    plt.show()
plot_aqi_vs_density(df)

# %% [markdown]
# #### Tendance du AQI en fonction du revenu moyen

# %%
def plot_aqi_vs_income(df):
    aqi_col = 'AQI_x'  # ou 'AQI_y', selon ce qui est affiché dans df.columns
    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=df, x='Average Income (USD)', y=aqi_col)
    plt.title('Tendance du AQI en fonction du revenu moyen')
    plt.xlabel('Revenu moyen (USD)')
    plt.ylabel(aqi_col)
    plt.show()
plot_aqi_vs_income(df)
